# %% [markdown]
# # Python Matplotlib
#
#
# Most of the Matplotlib utilities lies under the **pyplot** submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt
# or 
from matplotlib import pyplot as plt

# %% [markdown]
# ## Matplotlib Plotting

# %%
# Plotting x and y points

from matplotlib import pyplot as plt

# x-axis values
x = [5, 2, 9, 4, 7]

  
# Y-axis values
y = [10, 5, 8, 4, 2]
  
# Function to plot
plt.plot(x,y)
  
# function to show the plot
plt.show()

# %% [markdown]
# * The plot() function is used to draw points (markers) in a diagram.
#
# * By default, the plot() function draws a line from point to point.
#
# * The function takes parameters for specifying points in the diagram.

# %% [markdown]
# **Plotting Without Line**
# To plot only the markers, use shortcut string notation parameter 'o', which means 'rings'.

# %%
# To draw 2 points , one at position (1,4) and other at (5,3)
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 5])
ypoints = np.array([4, 3])

plt.plot(xpoints, ypoints, 'o')
plt.show()
# To plot the above with red circles
plt.plot(xpoints, ypoints, 'ro')
plt.show()

# %% [markdown]
# ## Matplotlib Markers and Lines

# %%
import matplotlib.pyplot as plt

x = [5, 2, 9, 4, 7]
y = [10, 5, 8, 4, 2]
# use the keyword argument **marker** to emphasize each point with a specified marker
plt.plot(x,y,marker='o')
plt.show()
plt.plot(x,y,marker='*')
plt.show()

# Use **linestyle**, or shorter **ls**, to change the style of the plotted line
plt.plot(x,y,linestyle='dotted')  
plt.show()

# Use **color** or the shorter **c** to set the color of the line
plt.plot(x,y,color='red')
plt.show()

# You can use also use the shortcut string notation parameter to specify the marker and is written with this syntax:
# marker|line|color
plt.plot(x,y,'o:r') #o is marker,:stands for dotted lines,r is color
plt.show()

# %% [markdown]
# ### With just a little bit of extra work we can easily plot multiple lines at once, and add a title, [legend](https://www.geeksforgeeks.org/matplotlib-pyplot-legend-in-python/), and axis labels:

# %%
import matplotlib.pyplot as plt
import numpy as np
# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points using matplotlib
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])
plt.show()

# %% [markdown]
# ## Matplotlib Subplots
# You can plot different things in the same figure using the [subplot](https://www.w3schools.com/python/matplotlib_subplots.asp) function. Here is an example:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2, 1, 2)     # two plots will be displayed on top of each other instead of side-by-side
# .subplot(nrows,ncolumns,index)

# Make the second plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the first subplot as active, and make the first plot.
plt.subplot(2, 1, 1)
plt.plot(x, y_cos)
plt.title('Cosine')

# Show the figure.
plt.show()

# %% [markdown]
# ## Matplotlib Scatter
#
# ### Creating Scatter Plots
#
# With Pyplot, you can use the **scatter()** function to draw a scatter plot.
#
# The **scatter()** function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis.Example:

# %%
# importing matplotlib module 
from matplotlib import pyplot as plt
  
# x-axis values
x = [5, 2, 9, 4, 7]
  
# Y-axis values
y = [10, 5, 8, 4, 2]
  
# Function to plot scatter
plt.scatter(x, y)
  
# function to show the plot
plt.show()

# %% [markdown]
# ### To read more about Scatter plots , check out [this](https://www.w3schools.com/python/matplotlib_scatter.asp)

# %% [markdown]
# ##  Bars
# ### Creating Bars
# With Pyplot, you can use the **bar()** function to draw bar graphs

# %%
from matplotlib import pyplot as plt

x = [5, 2, 9, 4, 7]
  
y = [10, 5, 8, 4, 2]
  
# Function to plot the bar
plt.bar(x,y)
  
# function to show the plot
plt.show()

# %% [markdown]
# ### For more information about bars , head over to [this](https://www.w3schools.com/python/matplotlib_bars.asp)

# %% [markdown]
# ## Histograms
#
# In Matplotlib, we use the **hist()** function to create histograms.
#
# The **hist()** function will use an array of numbers to create a histogram, the array is sent into the function as an argument.
#
# For simplicity we use NumPy to randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10.For this we use **[np.random.normal()](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html)** to get a Normal Data Distribution.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ### You can also see this [documentation](https://matplotlib.org/stable/gallery/statistics/hist.html) to know more about histograms

# %% [markdown]
# ## Pie Charts
#
# ### See all about **Pie charts** [here](https://www.w3schools.com/python/matplotlib_pie_charts.asp)

# %% [markdown]
# ### You can read much more about Matplotlib in this  [Matplotlib Documentation](https://matplotlib.org/Matplotlib.pdf).
